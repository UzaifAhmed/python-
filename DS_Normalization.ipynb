# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
original_dataset = pd.read_excel('Normal Distribution.xlsx', skiprows=9, index_col=0)

# %%
original_dataset
# Out:
#      Original dataset Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# NaN        567.450000        NaN        NaN         NaN         NaN
# NaN        572.450000     Task 1       Mean  743.027083         NaN
# NaN        572.450000        NaN    St. dev   73.953061         NaN
# NaN        589.116667        NaN        NaN         NaN         NaN
# NaN        613.866667   Task 3.1        NaN         NaN         NaN
# ..                ...        ...        ...         ...         ...
# NaN        842.866667        NaN        NaN         NaN         NaN
# NaN        849.616667        NaN        NaN         NaN         NaN
# NaN        874.700000        NaN        NaN         NaN         NaN
# NaN        878.783333        NaN        NaN         NaN         NaN
# NaN        897.450000        NaN        NaN         NaN         NaN
#
#      Unnamed: 6  Unnamed: 7  Subtract mean Unnamed: 9 Unnamed: 10  \
# NaN         NaN         NaN    -175.577083        NaN         NaN
# ...

# %%
data = original_dataset['Original dataset']

# %%
data.mean()
# Out:
# 743.0270833333332

# %%
X = data.std()

# %%
X.round(Decimal=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1e5ce5c30d92> in <module>
# ----> 1 X.round(Decimal=2)
#
# AttributeError: 'float' object has no attribute 'round'
