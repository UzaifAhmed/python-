# %%
import pandas as pd

# %%
# pd.read_excel('path_to_file.xls',
#               sheetname='Sheet1', header=[0, 1, 2],
#               skiprows=3, index_col=0)  # etc.
data = pd.read_csv('data.csv')

# %%
data
# Out:
#     Customer ID      Entity        Name   Surname  Age at time of purchase  \
# 0         C0028  Individual     Madalyn    Mercer                     19.0
# 1         C0027  Individual        Lara  Carrillo                     22.0
# 2         C0112  Individual     Donavan   Flowers                     22.0
# 3         C0160  Individual      Darien    Dorsey                     22.0
# 4         C0014  Individual  Alessandra     Perry                     25.0
# ..          ...         ...         ...       ...                      ...
# 190       C0174        Firm     Marleez        Co                      NaN
# 191       C0174        Firm     Marleez        Co                      NaN
# 192       C0174        Firm     Marleez        Co                      NaN
# 193       C0174        Firm     Marleez        Co                      NaN
# 194       C0174        Firm     Marleez        Co                      NaN
#
# ...

# %%
data['Gender'].fillna('Firm',inplace=True)

# %%
data['Gender'].value_counts()
# Out:
# M       108
# F        70
# Firm     17
# Name: Gender, dtype: int64

# %%
data['Gender']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 190    Firm
# 191    Firm
# 192    Firm
# 193    Firm
# 194    Firm
# Name: Gender, Length: 195, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
y = data['Gender'].value_counts()
genders = ['Males','Females','Firms']
plt.legend(title='Genders:')
plt.pie(y,autopct='%f%%',labels = genders)
plt.show()
# Out:
# No handles with labels found to put in legend.
