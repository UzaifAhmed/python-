# %% [markdown]
# 7-1. Rental Car: Write a program that asks the user what kind of rental car they
# would like. Print a message about that car, such as “Let me see if I can find you
# a Subaru.”

# %%
kind = input('Which Car do you want?\n')
print(f'Let me see if I can find you a {kind.title()}')
# Out:
# Which Car do you want?
# Mercedes
# Let me see if I can find you a Mercedes

# %% [markdown]
# 7-2. Restaurant Seating: Write a program that asks the user how many people
# are in their dinner group. If the answer is more than eight, print a message saying they’ll have to wait for a table. Otherwise, report that their table is ready.

# %%
people = int(input('ow many people are in your dinner group?\n'))

if people > 8:
    print('You have to wait for a table')
else:
    print('Your table is ready')
# Out:
# ow many people are in your dinner group?
# 8
# Your table is ready

# %% [markdown]
# 7-3. Multiples of Ten: Ask the user for a number, and then report whether the
# number is a multiple of 10 or not.

# %%
number = int(input('Enter a number: '))

if number%10==0:
    print(f'Yes, number {number} is multiple of 10')
else:
    print(f'Sorry, number {number} is not multiple of 10')
# Out:
# Enter a number: 16
# Sorry, number 16 is not multiple of 10

# %% [markdown]
# 7-4. Pizza Toppings: Write a loop that prompts the user to enter a series of
# pizza toppings until they enter a 'quit' value. As they enter each topping,
# print a message saying you’ll add that topping to their pizza.

# %%
topping_list = []
flag = True

while(flag):
    toppings = input('Please Enter Topping you want: ')
    print('or Enter quit')
    topping_list.append(toppings.title())
    if toppings == 'quit':
        topping_list.pop()
        print('We will add',end=" ")
        for x in topping_list:
            print(x,end=" ")
        print('in your Pizza')
        flag = False
# Out:
# Please Enter Topping you want: pepper
# or Enter quit
# Please Enter Topping you want: mushroom
# or Enter quit
# Please Enter Topping you want: quit
# or Enter quit
# We will add Pepper Mushroom in your Pizza

# %% [markdown]
# 7-5. Movie Tickets: A movie theater charges different ticket prices depending on
# a person’s age. If a person is under the age of 3, the ticket is free; if they are
# between 3 and 12, the ticket is 10 dollars; and if they are over age 12, the ticket is 15 dollars. Write a loop in which you ask users their age, and then tell them the cost
# of their movie ticket.

# %%
age = int(input('Enter your age: '))

if age < 3:
    print('The ticket is free')
elif age < 12:
    print('The ticket is $10')
else:
    print('The ticket is $15')
# Out:
# Enter your age: 4
# The ticket is $10

# %% [markdown]
# 7-6. Three Exits: Write different versions of either Exercise 7-4 or Exercise 7-5
# that do each of the following at least once:<Br>
# •	 Use a conditional test in the while statement to stop the loop.

# %%
topping_list = []
toppings = input('Please Enter Topping you want: ')
print('or Enter quit')

while(toppings != 'quit'):
    
    topping_list.append(toppings.title())
    if toppings == 'quit':
        topping_list.pop()
        print('We will add',end=" ")
        for x in topping_list:
            print(x,end=" ")
        print('in your Pizza')
    toppings = input('Please Enter Topping you want: ')
    print('or Enter quit')
# Out:
# Please Enter Topping you want: pepper
# or Enter quit
# Please Enter Topping you want: mushroom
# or Enter quit
# Please Enter Topping you want: quit
# or Enter quit

# %% [markdown]
# •	 Use an active variable to control how long the loop runs.

# %%
topping_list = []
flag = True

while(flag):
    toppings = input('Please Enter Topping you want: ')
    print('or Enter quit')
    topping_list.append(toppings.title())
    if toppings == 'quit':
        topping_list.pop()
        print('We will add',end=" ")
        for x in topping_list:
            print(x,end=" ")
        print('in your Pizza')
        flag = False
# Out:
# Please Enter Topping you want: cheese
# or Enter quit
# Please Enter Topping you want: quit
# or Enter quit
# We will add Cheese in your Pizza

# %% [markdown]
# •	 Use a break statement to exit the loop when the user enters a 'quit' value.

# %%
topping_list = []
flag = True

while(flag):
    toppings = input('Please Enter Topping you want: ')
    print('or Enter quit')
    topping_list.append(toppings.title())
    if toppings == 'quit':
        topping_list.pop()
        print('We will add',end=" ")
        for x in topping_list:
            print(x,end=" ")
        print('in your Pizza')
        break
# Out:
# Please Enter Topping you want: cheeze
# or Enter quit
# Please Enter Topping you want: mayonise
# or Enter quit
# Please Enter Topping you want: quit
# or Enter quit
# We will add Cheeze Mayonise in your Pizza

# %% [markdown]
# 7-7. Infinity: Write a loop that never ends, and run it. (To end the loop, press
# ctrl-C or close the window displaying the output.)

# %%
while(True):
    print('Never ends')
# Out:
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# Never ends
# ...

# %% [markdown]
# 7-8. Deli: Make a list called sandwich_orders and fill it with the names of various sandwiches. Then make an empty list called finished_sandwiches. Loop
# through the list of sandwich orders and print a message for each order, such
# as I made your tuna sandwich. As each sandwich is made, move it to the list
# of finished sandwiches. After all the sandwiches have been made, print a
# message listing each sandwich that was made.

# %%
sandwich_orders = ['club sandwich','vege sandwich','chilli sandwich']
finished_sandwiches = []

for a in sandwich_orders:
    print(f'I made your {a}')
    finished_sandwiches.append(a)
# Out:
# I made your club sandwich
# I made your vege sandwich
# I made your chilli sandwich

# %% [markdown]
# 7-9. No Pastrami: Using the list sandwich_orders from Exercise 7-8, make sure
# the sandwich 'pastrami' appears in the list at least three times. Add code
# near the beginning of your program to print a message saying the deli has
# run out of pastrami, and then use a while loop to remove all occurrences of
# 'pastrami' from sandwich_orders. Make sure no pastrami sandwiches end up
# in finished_sandwiches.

# %%
sandwich_orders = ['tuna', 'pastrami', 'egg', 'pastrami', 'vegetables', 'Ham', 'pastrami']
finished_sandwiches = []
 
print("Sorry to inform you that pastrami has been sold out")
while 'pastrami' in sandwich_orders:
    sandwich_orders.remove('pastrami')
 
while sandwich_orders:
    sandwich = sandwich_orders.pop()
    finished_sandwiches.append(sandwich)
    print("I made your "+sandwich+" sandwich.")
print(finished_sandwiches)
 
if 'pastrami' not in finished_sandwiches:
    print("No pastrami sandwich was made")
# Out:
# Sorry to inform you that pastrami has been sold out
# I made your Ham sandwich.
# I made your vegetables sandwich.
# I made your egg sandwich.
# I made your tuna sandwich.
# ['Ham', 'vegetables', 'egg', 'tuna']
# No pastrami sandwich was made

# %% [markdown]
# 7-10. Dream Vacation: Write a program that polls users about their dream
# vacation. Write a prompt similar to If you could visit one place in the world,
# where would you go? Include a block of code that prints the results of the poll

# %%
poll = []
while True:
    i = input('Enter one place in the world that you could visit (or enter end): ')
    if i == 'end':
        break
    else:
        poll.append(i)
poll
# Out:
# Enter one place in the world that you could visit (or enter end): Turkey
# Enter one place in the world that you could visit (or enter end): Saudi
# Enter one place in the world that you could visit (or enter end): Germany
# Enter one place in the world that you could visit (or enter end): Australia
# Enter one place in the world that you could visit (or enter end): end
# ['Turkey', 'Saudi', 'Germany', 'Australia']
