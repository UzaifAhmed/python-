# %%
#Person 1

from tkinter import *
from selenium import webdriver
import time


window = Tk()
window.title("Information Security")
window.geometry('510x300')
window.configure(bg='#f7f7f7')

p = StringVar()
g = StringVar()
a = StringVar()

def send():
    global first
    global third
    first = p.get()
    second = g.get()
    third = a.get()
    
    
    #generating key
    x = pow(int(second),int(third),int(first))
    
    L6.config(text="Your generated Key, x = "+str(x))
    
    Value = str(x)
    
    # Webdriver
    driver = webdriver.Edge(executable_path='C:/Users/Uzaif Ahmed/Downloads/edgedriver_win64/msedgedriver.exe')

    #Loading Website
    driver.get('https://www.codepile.net/pile/LRoxkG61')

    # 5 Seconds wait
    time.sleep(5)

    # Close Additional Popup
    frame = driver.find_element_by_xpath("//iframe[@class='sl-frame']")
    driver.switch_to.frame(frame)

    cross = driver.find_element_by_xpath("//i[@class='icon-ui-glyph-1_circle-remove']")
    cross.click()

    # 5 Seconds wait
    time.sleep(5)

    # Swithing to the frame of website
    driver.switch_to.parent_frame()


    textbox = driver.find_element_by_xpath('//*[@id="firepad"]/textarea')
    #Delete Previous
    textbox.clear()

    #Sends Key
    textbox.send_keys(Value)
    
    # 5 Seconds wait
    time.sleep(5)

    driver.close()

    
def fetch():
    
    # Webdriver
    driver = webdriver.Edge(executable_path='C:/Users/Uzaif Ahmed/Downloads/edgedriver_win64/msedgedriver.exe')

    #Loading Website
    driver.get('https://www.codepile.net/pile/LRoxkG61')

    # 5 Seconds wait
    time.sleep(5)

    # Close Additional Popup
    frame = driver.find_element_by_xpath("//iframe[@class='sl-frame']")
    driver.switch_to.frame(frame)

    cross = driver.find_element_by_xpath("//i[@class='icon-ui-glyph-1_circle-remove']")
    cross.click()

    # 5 Seconds wait
    time.sleep(5)

    # Swithing to the frame of website
    driver.switch_to.parent_frame()



    #Returns Text
    element_text = driver.find_element_by_xpath('//*[@id="firepad"]/div[2]/div')
    y = element_text.text
    
    # First = P , Third = a
    ka = pow(int(y),int(third),int(first))
    
    L9.config(text= str(ka))
    
    # 5 Seconds wait
    time.sleep(5)
    
    driver.close()
    
    


L1 = Label(window,text="...Diffie Hellman...",font="Times 25")
L1.configure(bg='#f7f7f7',fg='#008477')
L1.grid(row=0,column=1)

L2 = Label(window,text="Program Implementation",font="Arial")
L2.configure(bg='#f7f7f7',fg='#008477')
L2.grid(row=1,column=1)

L3 = Label(window,text="Prime Number (P):",font="Arial 11")
L3.configure(bg='#f7f7f7',fg='#008477')
L3.grid(row=4,column=0)

L4 = Label(window,text="Primitive Root  (G):",font="Arial 11")
L4.configure(bg='#f7f7f7',fg='#008477')
L4.grid(row=5,column=0)

L5 = Label(window,text="Private Key (Uzaif):",font="Arial 11")
L5.configure(bg='#f7f7f7',fg='#008477')
L5.grid(row=6,column=0)

L6 = Label(window,text="Your generated Key, x = ",font="Arial 10")
L6.configure(bg='#f7f7f7',fg='#008477')
L6.grid(row=8,column=0,columnspan=2)

L8 = Label(window,text="Your Secret Key",font="Arial 10 bold")
L8.configure(bg='#f7f7f7',fg='#008477')
L8.grid(row=9,column=0)

L9 = Label(window,text="Ka =",font="Times 40")
L9.configure(bg='#f7f7f7',fg='#008477')
L9.grid(row=10,column=0,rowspan=2)

L9 = Label(window,text="",font="Times 40")
L9.configure(bg='#f7f7f7',fg='#008477')
L9.grid(row=10,column=1,rowspan=2)



E1 = Entry(window,textvar=p)
E1.grid(row=4,column=1)

E2 = Entry(window,textvar=g)
E2.grid(row=5,column=1)

E3 = Entry(window,textvar=a)
E3.grid(row=6,column=1)



B2 = Button(window,text="Send",width=12,command=send)
B2.configure(bg='#00887a',fg='white',font="Arial 9 bold")
B2.grid(row=7,column=2)

B3 = Button(window,text="Fetch",width=12,command=fetch)
B3.configure(bg='#00887a',fg='white',font="Arial 9 bold")
B3.grid(row=11,column=2)



window.mainloop()

# %%
#Person 2

from tkinter import *
from selenium import webdriver
import time


window = Tk()
window.title("Information Security")
window.geometry('510x300')
window.configure(bg='#f7f7f7')

p = StringVar()
g = StringVar()
b = StringVar()

def check():
    global first
    global third
    first = p.get()
    second = g.get()
    third = b.get()
    
    
    #generating key
    y = pow(int(second),int(third),int(first))
    
    L6.config(text="Your generated Key, y = "+str(y))
    
    Value = str(y)
    
    
    # Webdriver
    driver = webdriver.Edge(executable_path='C:/Users/Uzaif Ahmed/Downloads/edgedriver_win64/msedgedriver.exe')

    #Loading Website
    driver.get('https://www.codepile.net/pile/LRoxkG61')

    # 5 Seconds wait
    time.sleep(5)

    # Close Additional Popup
    frame = driver.find_element_by_xpath("//iframe[@class='sl-frame']")
    driver.switch_to.frame(frame)

    cross = driver.find_element_by_xpath("//i[@class='icon-ui-glyph-1_circle-remove']")
    cross.click()

    # 5 Seconds wait
    time.sleep(5)

    # Swithing to the frame of website
    driver.switch_to.parent_frame()

    #Returns Text
    element_text = driver.find_element_by_xpath('//*[@id="firepad"]/div[2]/div')
    x = element_text.text
    
    # First = P , Third = b
    kb = pow(int(x),int(third),int(first))
    
    L9.config(text= str(kb))
    
    
    textbox = driver.find_element_by_xpath('//*[@id="firepad"]/textarea')
    #Delete Previous
    textbox.clear()

    #Sends Key
    textbox.send_keys(Value)
    
    # 5 Seconds wait
    time.sleep(5)

    driver.close()
    
    


L1 = Label(window,text="...Diffie Hellman...",font="Times 25")
L1.configure(bg='#f7f7f7',fg='#008477')
L1.grid(row=0,column=1)

L2 = Label(window,text="Program Implementation",font="Arial")
L2.configure(bg='#f7f7f7',fg='#008477')
L2.grid(row=1,column=1)

L3 = Label(window,text="Prime  Number  (P) :",font="Arial 11")
L3.configure(bg='#f7f7f7',fg='#008477')
L3.grid(row=4,column=0)

L4 = Label(window,text="Primitive  Root   (G) :",font="Arial 11")
L4.configure(bg='#f7f7f7',fg='#008477')
L4.grid(row=5,column=0)

L5 = Label(window,text="Private Key (Fayyaz):",font="Arial 11")
L5.configure(bg='#f7f7f7',fg='#008477')
L5.grid(row=6,column=0)

Space = Label(window,text="",font="Arial 11")
Space.configure(bg='#f7f7f7',fg='#008477')
Space.grid(row=7,column=1)

L6 = Label(window,text="Your generated Key, y = ",font="Arial 10")
L6.configure(bg='#f7f7f7',fg='#008477')
L6.grid(row=8,column=0,columnspan=2)

L8 = Label(window,text="Your Secret Key",font="Arial 10 bold")
L8.configure(bg='#f7f7f7',fg='#008477')
L8.grid(row=9,column=0)

L9 = Label(window,text="Kb =",font="Times 40")
L9.configure(bg='#f7f7f7',fg='#008477')
L9.grid(row=10,column=0,rowspan=2)

L9 = Label(window,text="",font="Times 40")
L9.configure(bg='#f7f7f7',fg='#008477')
L9.grid(row=10,column=1,rowspan=2)



E1 = Entry(window,textvar=p)
E1.grid(row=4,column=1)

E2 = Entry(window,textvar=g)
E2.grid(row=5,column=1)

E3 = Entry(window,textvar=b)
E3.grid(row=6,column=1)



B3 = Button(window,text="Check",width=12,command=check)
B3.configure(bg='#00887a',fg='white',font="Arial 9 bold")
B3.grid(row=11,column=2)



window.mainloop()
